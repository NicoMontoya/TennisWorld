# %%
import pandas as pd

atp_2000 = pd.read_excel("atp_2000.xls")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

atp_2000.head()
# Out:
#    ATP  Location                          Tournament       Date  \
# 0    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 1    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 2    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 3    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 4    1  Adelaide  Australian Hardcourt Championships 2000-01-03
#
#           Series    Court Surface      Round  Best of       Winner  \
# 0  International  Outdoor    Hard  1st Round        3   Dosedel S.
# 1  International  Outdoor    Hard  1st Round        3   Enqvist T.
# 2  International  Outdoor    Hard  1st Round        3    Escude N.
# 3  International  Outdoor    Hard  1st Round        3   Federer R.
# 4  International  Outdoor    Hard  1st Round        3  Fromberg R.
#
#             Loser WRank LRank   W1   L1   W2   L2   W3   L3  W4  L4  W5  L5  \
# 0     Ljubicic I.    63    77  6.0  4.0  6.0  2.0  NaN  NaN NaN NaN NaN NaN
# ...

# %%
atp_2000.describe()
# Out:
#                ATP      Best of           W1           L1           W2  \
# count  2963.000000  2963.000000  2949.000000  2949.000000  2929.000000
# mean     34.573405     3.353021     5.786707     4.056968     5.730966
# std      18.783485     0.762636     1.224307     1.811170     1.295748
# min       1.000000     3.000000     0.000000     0.000000     0.000000
# 25%      20.000000     3.000000     6.000000     3.000000     6.000000
# 50%      34.000000     3.000000     6.000000     4.000000     6.000000
# 75%      50.500000     3.000000     6.000000     6.000000     6.000000
# max      69.000000     5.000000     7.000000     7.000000     7.000000
#
#                 L2           W3           L3          W4          L4  \
# count  2929.000000  1368.000000  1368.000000  267.000000  267.000000
# mean      3.805736     6.000000     3.570175    5.779026    3.838951
# std       1.866119     0.940824     1.753096    1.277278    1.897837
# ...

# %%
Dosedel = atp_2000[(atp_2000["Winner"] == "Dosedel S.") | (atp_2000["Loser"] == "Dosedel S.")]

# %%
len(Dosedel[Dosedel["Winner"] == "Dosedel S."])
# Out:
# 17

# %%
len(Dosedel[Dosedel["Loser"] == "Dosedel S."])
# Out:
# 20

# %%
max(Dosedel[Dosedel["Loser"] == "Dosedel S."]["LRank"])
# Out:
# 70

# %%
min((Dosedel[Dosedel["Loser"] == "Dosedel S."]["LRank"]))
# Out:
# 50

# %%
Dosedel.head()
# Out:
#      ATP  Location                          Tournament       Date  \
# 0      1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 17     1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 128    5    Sydney                Sydney International 2000-01-10
# 141    5    Sydney                Sydney International 2000-01-10
# 148    5    Sydney                Sydney International 2000-01-10
#
#             Series    Court Surface          Round  Best of       Winner  \
# 0    International  Outdoor    Hard      1st Round        3   Dosedel S.
# 17   International  Outdoor    Hard      2nd Round        3    Escude N.
# 128  International  Outdoor    Hard      1st Round        3   Dosedel S.
# 141  International  Outdoor    Hard      2nd Round        3   Dosedel S.
# 148  International  Outdoor    Hard  Quarterfinals        3  Corretja A.
#
#             Loser WRank LRank   W1   L1   W2   L2   W3   L3  W4  L4  W5  L5  \
# ...
